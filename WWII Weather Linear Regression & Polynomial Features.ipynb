# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Summary of Weather.csv.zip")
# Out:
# /tmp/ipykernel_4622/2024405518.py:1: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Summary of Weather.csv.zip")

# %%
df.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 31 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STA          119040 non-null  int64
#  1   Date         119040 non-null  object
#  2   Precip       119040 non-null  object
#  3   WindGustSpd  532 non-null     float64
#  4   MaxTemp      119040 non-null  float64
#  5   MinTemp      119040 non-null  float64
#  6   MeanTemp     119040 non-null  float64
#  7   Snowfall     117877 non-null  object
#  8   PoorWeather  34237 non-null   object
#  9   YR           119040 non-null  int64
#  10  MO           119040 non-null  int64
#  11  DA           119040 non-null  int64
#  12  PRCP         117108 non-null  object
#  13  DR           533 non-null     float64
#  14  SPD          532 non-null     float64
#  15  MAX          118566 non-null  float64
#  16  MIN          118572 non-null  float64
#  17  MEA          118542 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['STA', 'Date', 'Precip', 'WindGustSpd', 'MaxTemp', 'MinTemp',
#        'MeanTemp', 'Snowfall', 'PoorWeather', 'YR', 'MO', 'DA', 'PRCP', 'DR',
#        'SPD', 'MAX', 'MIN', 'MEA', 'SNF', 'SND', 'FT', 'FB', 'FTI', 'ITH',
#        'PGT', 'TSHDSBRSGF', 'SD3', 'RHX', 'RHN', 'RVG', 'WTE'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# STA                 0
# Date                0
# Precip              0
# WindGustSpd    118508
# MaxTemp             0
# MinTemp             0
# MeanTemp            0
# Snowfall         1163
# PoorWeather     84803
# YR                  0
# MO                  0
# DA                  0
# PRCP             1932
# DR             118507
# SPD            118508
# MAX               474
# MIN               468
# MEA               498
# SNF              1163
# SND            113477
# FT             119040
# FB             119040
# FTI            119040
# ITH            119040
# PGT            118515
# TSHDSBRSGF      84803
# SD3            119040
# RHX            119040
# RHN            119040
# RVG            119040
# WTE            119040
# dtype: int64

# %%
df[df.isnull().any(axis = 1)]
# Out:
#           STA        Date Precip  WindGustSpd    MaxTemp    MinTemp  \
# 0       10001    1942-7-1  1.016          NaN  25.555556  22.222222
# 1       10001    1942-7-2      0          NaN  28.888889  21.666667
# 2       10001    1942-7-3   2.54          NaN  26.111111  22.222222
# 3       10001    1942-7-4   2.54          NaN  26.666667  22.222222
# 4       10001    1942-7-5      0          NaN  26.666667  21.666667
# ...       ...         ...    ...          ...        ...        ...
# 119035  82506  1945-12-27      0          NaN  28.333333  18.333333
# 119036  82506  1945-12-28  9.906          NaN  29.444444  18.333333
# 119037  82506  1945-12-29      0          NaN  28.333333  18.333333
# 119038  82506  1945-12-30      0          NaN  28.333333  18.333333
# 119039  82506  1945-12-31      0          NaN  29.444444  17.222222
#
#          MeanTemp Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  \
# ...

# %%
df.isnull().sum() / len(df)  * 100
# Out:
# STA              0.000000
# Date             0.000000
# Precip           0.000000
# WindGustSpd     99.553091
# MaxTemp          0.000000
# MinTemp          0.000000
# MeanTemp         0.000000
# Snowfall         0.976983
# PoorWeather     71.239079
# YR               0.000000
# MO               0.000000
# DA               0.000000
# PRCP             1.622984
# DR              99.552251
# SPD             99.553091
# MAX              0.398185
# MIN              0.393145
# MEA              0.418347
# SNF              0.976983
# SND             95.326781
# FT             100.000000
# FB             100.000000
# FTI            100.000000
# ITH            100.000000
# PGT             99.558972
# TSHDSBRSGF      71.239079
# SD3            100.000000
# RHX            100.000000
# RHN            100.000000
# RVG            100.000000
# WTE            100.000000
# dtype: float64

# %%
df.shape
# Out:
# (119040, 31)

# %%
df.columns=df.columns.str.strip()
drop_columns = ["FT","FB","FTI","ITH","SD3","RHX","RHN","RVG","WTE","MAX","MIN","WindGustSpd","DR","SPD","PGT","SND","MEA","SNF","PRCP","PoorWeather","TSHDSBRSGF"]
df.drop(columns=drop_columns,inplace=True,axis=1, errors='ignore')

# %%
df.shape
# Out:
# (119040, 10)

# %%
df.isnull().sum()
# Out:
# STA            0
# Date           0
# Precip         0
# MaxTemp        0
# MinTemp        0
# MeanTemp       0
# Snowfall    1163
# YR             0
# MO             0
# DA             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['STA', 'Date', 'Precip', 'MaxTemp', 'MinTemp', 'MeanTemp', 'Snowfall',
#        'YR', 'MO', 'DA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    119040 non-null  object
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  117877 non-null  object
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 9.1+ MB

# %%
df["Precip"].unique()
# Out:
# array(['1.016', '0', '2.54', 'T', '3.556', '0.508', '0.254', '1.778',
#        '3.302', '0.762', '5.588', '5.08', '2.032', '25.654', '40.132',
#        '19.05', '23.876', '4.064', '12.192', '2.794', '33.274', '19.304',
#        '47.752', '6.35', '3.048', '8.382', '10.16', '27.178', '30.48',
#        '45.212', '10.668', '15.494', '57.658', '58.166', '11.43',
#        '31.242', '17.78', '26.924', '26.67', '6.604', '5.334', '4.826',
#        '7.62', '8.636', '7.874', '12.446', '90.932', '13.462', '11.938',
#        '5.842', '4.318', '6.096', '9.144', '4.572', '9.906', '9.652',
#        '1.524', '13.97', '17.272', '33.528', '1.27', '13.716', '8.128',
#        '22.352', '39.116', '36.068', '98.044', '3.81', '14.986', '78.232',
#        '146.304', '14.732', '21.844', '120.904', '42.164', '23.368',
#        '21.082', '44.958', '2.286', '50.038', '17.526', '51.054', '7.112',
#        '25.4', '7.366', '16.256', '46.736', '8.89', '24.638', '11.684',
# ...

# %%
df[df["Precip"]== "T"]
# Out:
#           STA        Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  \
# 6       10001    1942-7-7      T  28.333333  22.777778  25.555556      0.0
# 8       10001    1942-7-9      T  27.222222  22.777778  25.000000      0.0
# 15      10001   1942-7-16      T  26.111111  21.111111  23.333333      0.0
# 16      10001   1942-7-17      T  28.333333  22.222222  25.555556      0.0
# 17      10001   1942-7-18      T  26.666667  21.111111  23.888889      0.0
# ...       ...         ...    ...        ...        ...        ...      ...
# 119001  82506  1945-11-23      T  26.666667  18.333333  22.222222      0.0
# 119006  82506  1945-11-28      T  28.333333  21.111111  24.444444      0.0
# 119014  82506   1945-12-6      T  27.222222  17.777778  22.222222      0.0
# 119018  82506  1945-12-10      T  30.000000  19.444444  24.444444      0.0
# 119031  82506  1945-12-23      T  28.333333  18.333333  23.333333      0.0
#
#         YR  MO  DA
# 6       42   7   7
# 8       42   7   9
# ...

# %%
df['Precip'] = df['Precip'].replace('T', 0)

# %%
df['Precip'] = pd.to_numeric(df['Precip'], errors='coerce')
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[["Precip","MaxTemp","MinTemp","MeanTemp","YR","Mo","DA"]] = df[["Precip","MaxTemp","MinTemp","MeanTemp","YR","MO","DA"]].astype(int)

# %%
df["Snowfall"].unique()
# Out:
# array([0.0, nan, '0', '22.86', '33.02', '30.48', '2.54', '5.08', '10.16',
#        '7.62', '20.32', '15.24', '17.78', '12.7', '25.4', '27.94',
#        '43.18', '38.1', '45.72', '53.34', '58.42', '66.04', '76.2',
#        '81.28', '73.66', '63.5', '50.8', '48.26', '60.96', '55.88',
#        '35.56', '78.74', '40.64', '86.36', '83.82', '68.58', '#VALUE!',
#        10.16, 7.62, 15.24, 2.54, 5.08, 12.7], dtype=object)

# %%
df['Snowfall'] = pd.to_numeric(df['Snowfall'], errors='coerce')
df["Snowfall"] = df["Snowfall"].replace("#VALUE!",np.nan)
df["Snowfall"]=df["Snowfall"].fillna(df["Snowfall"].mean())

# %%
df.isnull().sum()
# Out:
# STA         0
# Date        0
# Precip      0
# MaxTemp     0
# MinTemp     0
# MeanTemp    0
# Snowfall    0
# YR          0
# MO          0
# DA          0
# Mo          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  datetime64[ns]
#  2   Precip    119040 non-null  int64
#  3   MaxTemp   119040 non-null  int64
#  4   MinTemp   119040 non-null  int64
#  5   MeanTemp  119040 non-null  int64
#  6   Snowfall  119040 non-null  float64
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  Mo        119040 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(9)
# memory usage: 10.0 MB

# %%
df.describe()
# Out:
#                  STA                           Date         Precip  \
# count  119040.000000                         119040  119040.000000
# mean    29659.435795  1944-04-27 16:35:07.741935616       3.083258
# min     10001.000000            1940-01-01 00:00:00       0.000000
# 25%     11801.000000            1943-09-03 00:00:00       0.000000
# 50%     22508.000000            1944-06-26 00:00:00       0.000000
# 75%     33501.000000            1945-03-15 00:00:00       0.000000
# max     82506.000000            1945-12-31 00:00:00     307.000000
# std     20953.209402                            NaN      10.699274
#
#              MaxTemp        MinTemp       MeanTemp       Snowfall  \
# count  119040.000000  119040.000000  119040.000000  119040.000000
# mean       26.627361      17.378772      21.955788       0.245544
# min       -33.000000     -38.000000     -35.000000       0.000000
# 25%        25.000000      15.000000      20.000000       0.000000
# ...

# %%
df.corr()
# Out:
#                STA      Date    Precip   MaxTemp   MinTemp  MeanTemp  \
# STA       1.000000  0.119813  0.013991  0.092060  0.057917  0.077828
# Date      0.119813  1.000000  0.018789  0.046930 -0.004949  0.022092
# Precip    0.013991  0.018789  1.000000  0.005080  0.087376  0.047315
# MaxTemp   0.092060  0.046930  0.005080  1.000000  0.875424  0.968055
# MinTemp   0.057917 -0.004949  0.087376  0.875424  1.000000  0.963299
# MeanTemp  0.077828  0.022092  0.047315  0.968055  0.963299  1.000000
# Snowfall -0.058259 -0.012176 -0.011571 -0.321046 -0.305122 -0.321961
# YR        0.121408  0.968056  0.009424  0.039001 -0.022202  0.009423
# MO       -0.008592  0.107463  0.037010  0.031828  0.069626  0.051083
# DA        0.000903  0.011641  0.000488 -0.005166 -0.002254 -0.004233
# Mo       -0.008592  0.107463  0.037010  0.031828  0.069626  0.051083
#
#           Snowfall        YR        MO        DA        Mo
# STA      -0.058259  0.121408 -0.008592  0.000903 -0.008592
# ...

# %%
sns.heatmap(df.corr())
plt.show()

# %%
df.head()
# Out:
#      STA       Date  Precip  MaxTemp  MinTemp  MeanTemp  Snowfall  YR  MO  DA  \
# 0  10001 1942-07-01       1       25       22        23       0.0  42   7   1
# 1  10001 1942-07-02       0       28       21        25       0.0  42   7   2
# 2  10001 1942-07-03       2       26       22        24       0.0  42   7   3
# 3  10001 1942-07-04       2       26       22        24       0.0  42   7   4
# 4  10001 1942-07-05       0       26       21        24       0.0  42   7   5
#
#    Mo
# 0   7
# 1   7
# 2   7
# 3   7
# 4   7

# %% [markdown]
# #LİNEAR REGRESSİON:

# %%
X = df[["Precip","MinTemp","Snowfall","YR","MO"]]
y = df["MaxTemp"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25 , random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, r2_score

# %%
Regression = LinearRegression()

# %%
Regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = Regression.predict(X_test)

# %%
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7721605337662538

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("MSE:" , mse)
print("MAE:" , mae)
# Out:
# MSE: 17.05788735164929
# MAE: 3.124777885374232

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %% [markdown]
# # Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2, include_bias=True)

# %%
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
X_train_poly
# Out:
# array([[ 1.        , -0.28685278,  0.9280169 , ...,  1.10539993,
#          0.69892363,  0.4419163 ],
#        [ 1.        , -0.28685278,  0.44230426, ...,  0.02933073,
#         -0.08585553,  0.25131223],
#        [ 1.        , -0.28685278, -2.47197163, ...,  1.10539993,
#         -1.1400636 ,  1.17581427],
#        ...,
#        [ 1.        , -0.28685278,  0.56373242, ...,  0.02933073,
#          0.21370215,  1.5570224 ],
#        [ 1.        , -0.28685278,  0.19944793, ...,  6.09641199,
#         -3.08094953,  1.5570224 ],
#        [ 1.        , -0.28685278,  0.56373242, ...,  0.50247634,
#         -0.47122445,  0.4419163 ]])

# %%
regression = LinearRegression()

# %%
regression.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test_poly)
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.79513497709541

# %% [markdown]
# # #LASSO

# %%
from sklearn.linear_model import LassoCV
lasso = LassoCV(cv=5)
lasso.fit(X_train , y_train)
y_pred = lasso.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("R2 Score:",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean Absolute Error: 3.1241475807945522
# Mean Squared Error: 17.05839828348977
# R2 Score: 0.7721537093315851
